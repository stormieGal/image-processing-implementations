# %% [markdown]
# ## Digitalisation

# %%
def digitalization(values, width, height, num_grey_levels):
    
    min_amplitude = min(values["y_coord"])
    max_amplitude = max(values["y_coord"])
    
    def fill_resulting_image(nrows, ncols):
        res = []
        for i in range(ncols):
            for j in range(nrows):
                res[j][i] = 0
    
    def sampling():
        step = int(len(values["x_coord"]) / width)
        return values["x_coord"][0::step]
        
    def assign_pixel_value(value, levels):
        for i in range(len(levels.keys())):
            if value <= levels[f"level{i}"]:
                levels[f"level{i}"]
        
    def quantization():
        levels = {}
#         print(f"MAX_AMPLITUDE: {max_amplitude}")
        step_quant = (max_amplitude - min_amplitude) / num_grey_levels
        k=1
#         print(f"STEP QuanT: {step_quant}")
        for i in range(num_grey_levels):
#             print(min_amplitude)
            levels[f"level{i}"] = min_amplitude + step_quant*k
#             print(min_amplitude + step_quant * k)
            k += 1
        samples = sampling()
        num_samples = len(samples)
        new_img = fill_resulting_image(height ,total_samples)
    
        for i in range(total_samples):
            for j in range(total_samples):
#                 if values["x_coord"][j][i] JE SUIS BLOQUEE
                new_img[j][i] = assign_pixel_value(actual_pixel)
    
        return levels
        
#     samp = sampling()
#     if len(res) != width:
#         print(f"This image cannot be digitalisation in the given dimension. The result is for width: {len(res)}")
    quan = quantization()
    return quan
#Get continuous values from a fucntion to achieve this.

# %%
def digitalization(values, width, height, num_grey_levels):
    
#     min_amplitude = min(values["y_coord"])
#     max_amplitude = max(values["y_coord"])

    min_amplitude = 0
    max_amplitude = 0
    a_sample = ()
    def min_max_amplitude(values):
        global min_amplitude, max_amplitude, a_sample
        for crop in values:
            a_sample = crop
            min_amplitude, max_amplitude = min(crop[2]), max(crop[2])
    
    def fill_resulting_image(nrows, ncols):
        res = []
        for i in range(ncols):
            for j in range(nrows):
                res[j][i] = 0
    
    def sampling():
        step = int(len(a_sample[0]) / width)
        return values["x_coord"][0::step]
        
    def assign_pixel_value(value, levels):
        for i in range(len(levels.keys())):
            if value <= levels[f"level{i}"]:
                levels[f"level{i}"]
        
    def quantization():
        levels = {}
#         print(f"MAX_AMPLITUDE: {max_amplitude}")
        step_quant = (max_amplitude - min_amplitude) / num_grey_levels
        k=1
#         print(f"STEP QuanT: {step_quant}")
        for i in range(num_grey_levels):
#             print(min_amplitude)
            levels[f"level{i}"] = min_amplitude + step_quant*k
#             print(min_amplitude + step_quant * k)
            k += 1
        samples = sampling()
        num_samples = len(samples)
        new_img = fill_resulting_image(height ,total_samples)
    
        for i in range(total_samples):
            for j in range(total_samples):
#                 if values["x_coord"][j][i] JE SUIS BLOQUEE
                new_img[j][i] = assign_pixel_value(actual_pixel)
    
        return levels
        
#     samp = sampling()
#     if len(res) != width:
#         print(f"This image cannot be digitalisation in the given dimension. The result is for width: {len(res)}")
    quan = quantization()
    return quan
#Get continuous values from a fucntion to achieve this.

# %%
#test digitalization
import random

X = [i for i in range(256)]
Y = list(X) # Copie sans referencement
# Z =  [ (1 + 3**(1/2)/2)*i for i in X]# amplitude

amplitudes = []
for i in range(len(X)): #column
    amplitudes.append(random.sample(range(256), len(Y)))
    
    
for i in range(len(X)):
    for j in range(len(Y)):
        if i != j:
            amplitudes[i][j] = 0

image_as_function = zip(X, Y, amplitudes)

# image_as_function[0]

# %%
# test digitilization OLD ONE
import random
i = 12
j = 25

# X = random.sample(range(10), 5)[0:]
# # len(X)
Y = [i ** 2 for i in X] # Une fonction croissante car la reponse doit etre proportionnelle a l'intensite de l'energie lumineuse incidente.
# data = {"x_coord":X, "y_coord": Y, "amplitude": }

# # data["x_coord"]

# # x = "mama"
# # data[f"{x}is"] = 5
# # data['mamais']

# digitalization(data, 50, 50, 60)
